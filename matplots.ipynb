# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style(style='darkgrid')

# %%
data = pd.Series(np.random.randn(1000), index = pd.date_range(1/1/2000, periods=1000))
data = data.cumsum()
data.plot()
plt.show()

# %%
plt.plot([1,2,3,4])
plt.ylabel('y axis')
plt.xlabel('xxx')
plt.show()

# %%
df = pd.DataFrame({'value':pd.Series([2,3,4,5])})

plt.plot(df.value,[3,6,8,9])
plt.ylabel('y axis')
plt.xlabel('xxx')
plt.show()

# %%
plt.plot([1,2,3,4,5], [5,4,8,9,6], 'y--')
plt.axis([0,7,3,10])
plt.show()

# %%
val = np.linspace(1,5,10)
plt.plot(val,val,'bo', val, val**2.5,'k', val,val**3, 'ys', val,val**4,'g-',linewidth=3.0)

plt.show()

# %% [markdown]
# # some text goes here ..
# this could have been used <before/>

# %%
plt.figure(1)
plt.subplot(211)
plt.plot([1,2,3])
#plt.subplot(222)
#plt.plot([4,7,9])

plt.subplot(223)
plt.plot([4,7,9], 'bo')
plt.subplot(224)
plt.plot([4,7,9],'ko')

plt.figure(2)
plt.subplot(211)
plt.plot([1,2,3])
plt.title('topper')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.grid()

plt.subplot(212)
val2 = np.linspace(0,5,100)
plt.plot(val2,np.cos(2*np.pi*val2),'k-')

plt.annotate('local max', xy=(2, 1), xytext=(3, 2),
            arrowprops=dict(facecolor='black', shrink=0.05),)
plt.ylim(-2,2)

plt.show()

# %% [markdown]
# Below is from a different tutorial http://www.labri.fr/perso/nrougier/teaching/matplotlib/

# %%
xVal = np.linspace(-2*np.pi,2*np.pi,256)
sine,cos = np.sin(xVal), np.cos(xVal)

plt.plot(xVal,sine,'g--')
plt.plot(xVal,cos, color = 'r')
plt.ylim(-1.5,1.5)
plt.xticks(np.linspace(-2*np.pi, 2*np.pi, 9))
plt.yticks(np.linspace(-1,1,3))

plt.show()

# %%
# uniform distribution. 
# arguments -> start, end, tuple in shape of returned array
np.random.uniform(1,5,(3,3))
# Out:
# array([[3.49910853, 4.6015921 , 3.45546823],
#        [2.21884745, 1.85704998, 2.48792138],
#        [1.40689626, 2.43947932, 1.90786086]])

# %%
# mean 0 and variance 1. standard normal distribution. tuple gives the dimension
np.random.randn(3,2)
# Out:
# array([[ 0.77060401, -0.54029659],
#        [ 0.23237537,  0.86505136],
#        [-0.15976669, -1.83520605]])

# %%
#random distribution between 0 and 1. the tuple gives the dimension of the array
np.random.rand(2,3)
# Out:
# array([[0.31497671, 0.2601857 , 0.55773814],
#        [0.15058999, 0.22654699, 0.82171487]])

# %%
# arguments -> mean, standard deviation, num of results
np.random.normal(2,7,10)
# Out:
# array([ 0.303856  ,  1.75024731, 16.80091511,  1.29431845, 17.74062808,
#        -6.66464785, -1.60615105,  3.58587978, 13.79471629, 18.35099382])

# %%
Xa = np.linspace(-np.pi, np.pi,256)
Ya = np.sin(2*Xa)
plt.plot(Xa,Ya,'b--')
plt.fill_between(Xa,Ya,facecolor='green')
plt.show()

# %%
Xr = np.random.normal(0,2,400)
Yr = np.random.normal(0,2,400)
Xb = np.random.normal(4,2,400)
Yb = np.random.normal(4,2,400)

plt.scatter(Xr,Yr, c='r', alpha =.4)
plt.scatter(Xb,Yb, c='b', alpha =.3)
plt.show()

# %%
eqs = []
eqs.append((r"$W^{3\beta}_{\delta_1 \rho_1 \sigma_2} = U^{3\beta}_{\delta_1 \rho_1} + \frac{1}{8 \pi 2} \int^{\alpha_2}_{\alpha_2} d \alpha^\prime_2 \left[\frac{ U^{2\beta}_{\delta_1 \rho_1} - \alpha^\prime_2U^{1\beta}_{\rho_1 \sigma_2} }{U^{0\beta}_{\rho_1 \sigma_2}}\right]$"))
eqs.append((r"$\frac{d\rho}{d t} + \rho \vec{v}\cdot\nabla\vec{v} = -\nabla p + \mu\nabla^2 \vec{v} + \rho \vec{g}$"))
eqs.append((r"$\int_{-\infty}^\infty e^{-x^2}dx=\sqrt{\pi}$"))
eqs.append((r"$E = mc^2 = \sqrt{{m_0}^2c^4 + p^2c^2}$"))
eqs.append((r"$F_G = G\frac{m_1m_2}{r^2}$"))
eqs.append("Prajeen ..")
eqs.append("Super man ..")


plt.axes([0.025,0.025,0.95,0.95])

for i in range(24):
    index = np.random.randint(0,len(eqs))
    eq = eqs[index]
    size = np.random.uniform(12,32)
    x,y = np.random.uniform(0,1,2)
    alpha = np.random.uniform(0.25,.75)
    plt.text(x, y, eq, ha='center', va='center', color="#11557c", alpha=alpha,
             transform=plt.gca().transAxes, fontsize=size, clip_on=True)

plt.xticks([]), plt.yticks([])
# savefig('../figures/text_ex.png',dpi=48)
plt.show()

# %%
dataF = pd.DataFrame({'numbers':pd.Series([2,3,4,5,2,3,4,7,8,2,2,3,4,7])})
sns.countplot(x='numbers',data=dataF)

plt.show()

# %%
ti = sns.load_dataset('titanic')
sns.barplot(x='class', y='age', data=ti)
plt.show()

# %%
sns.barplot(x='class', y='age', hue='who', data=ti)
plt.show()

# %%
sns.factorplot(x='class', y='age', hue='who', col='survived', data =ti, kind='bar')
plt.show()

# %%
iris = sns.load_dataset('iris')

sns.pairplot(iris, hue='species')
plt.show()

# %%
sns.pairplot(iris, vars=['sepal_width', 'sepal_length', 'petal_width'], hue='species', markers=['o','s','D'])
plt.show()

# %%
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
(ti[ti.deck.notnull()]).head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True

# %% [markdown]
# ### Documentation
# The following link is a great document of Visualization using python in general and seaborn in particular [click here](http://tomaugspurger.github.io/modern-6-visualization.html)
#
# It also talk about how scikit-learn can be grid-searched and visulalized - look at the end of the page
